# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = 'https://www.pythonscraping.com/pages/warandpeace.html'

html = urlopen(url)

bs = BeautifulSoup(html, 'html.parser')

# Any extra kwards that the function doesn recognize will be
# Used as tag attribute matchers
bs.find_all({'id': 'text'})


# Find all function is used to find tags based on their attributes and attribute values
# Out:
# []

# %%
html = urlopen(url)


# BeautifulSoup object:

# 1) BeautifulSouip object
bs = BeautifulSoup(html, 'html.parser')

# 2) Tag objects
tag = bs.h1
print(type(tag), tag)

#3) NavigableString objects
# used to represent text within a tag, rather than tags themselves.

#4 Comment object
# USed to find HTML comments
# Out:
# <class 'bs4.element.Tag'> <h1>War and Peace</h1>

# %%
url = 'https://www.vg.no'

req = urlopen(url)
bs = BeautifulSoup(req, 'html.parser')
# Out:
# <!DOCTYPE html>
#
# <html data-assets-url="https://www.vg.no/vgc/frimand/" data-base-path="https://www.vg.no" data-device="desktop" data-id="front" data-page-type="Frontpage" lang="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- Jasså, liker du å snoke i kildekoden? Det gjør vi også. Kom og snakk med oss da vel? Bli med på https://discord.gg/vgno -->
# <title>VG</title>
# <script id="pulse-queue">
# window.pulse = window.pulse || function() {
# (window.pulse.q = window.pulse.q || []).push(arguments);
# };
# </script>
# <script type="esms-options">
# {
# "skip": "\/frimand-api\/"
# }
# </script>
# <script type="importmap">
# {
# "imports": {
# "preact": "https://www.vg.no/vgc/retargeting-components/modules/preact/preact.js",
# "react": "https://www.vg.no/vgc/retargeting-components/modules/preact/compat.js",
# "react/jsx-runtime": "https://www.vg.no/vgc/retargeting-components/modules/preact/jsxRuntime.js",
# ...

# %%
i = 0
for article in bs.find_all('a', {'itemprop': 'url'}):
    print(article.)
    print('-------------')
    if i > 4:
        break
    i += 1
# Out:
# <a href="https://www.vg.no/forbruker/i/KMMVLy/et-helvete-jeg-ikke-unner-noen?utm_source=vgfront&amp;utm_content=hovedlopet_row1_pos1&amp;utm_medium=dre-66d174abb3a24eb17360b5f0" itemprop="url">
# <figure>
# <div style=" padding-bottom: 70.572207084469% ">
# ...
